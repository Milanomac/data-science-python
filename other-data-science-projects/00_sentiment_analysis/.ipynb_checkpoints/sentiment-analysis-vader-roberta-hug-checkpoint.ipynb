# %% [markdown]
# ## Sentiment Analysis in Python
#
# #### This notebook was created using https://www.youtube.com/watch?v=QpzMWQvxXWk&t=157s as an example. Here, we will be using 2 different techniques and we'll compare the results:
# - 'Bag of words' approach using VADER (Valence Aware Dictionary and sEntiment Reasoner)
# - Roberta Pretrained Model from Huggingface
#
# I added several improvements in addition to the code presented in the video, for example:
#
# - Instead of loading the provided csv file, I imported sqlite database using sqlite3 module and loaded it to a DF
# - Note that database.sqlite file was too large to be imported into github; it can be downloaded from: https://www.kaggle.com/code/robikscube/sentiment-analysis-python-youtube-tutorial/data?select=database.sqlite
# - Added annotations to the barplot (Figure 1)
# ----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Steps:
#
# 1. Step 0. Read in Data and NLTK Basics
# 2. Step 1. VADER Seniment Scoring
# 3. Step 3. Roberta Pretrained Model
# 4. Step 3. Combine and compare
# 5. Step 4: Review Examples:
# 6. Extra: The Transformers Pipeline

# %% [markdown]
# #### Step 0. Read in Data and NLTK Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# pip install nltk
import nltk

# %%
# Import necessary module
# import sqlite3

# conn = sqlite3.connect("database\\database.sqlite")

# # Query the sqlite_master table to get the names of all tables
# c = conn.cursor()
# c.execute("SELECT name FROM sqlite_master WHERE type='table';")
# table_names = c.fetchall()

# print(table_names)

# Query the database and load the result into a Pandas DataFrame
# df = pd.read_sql_query("SELECT * FROM Reviews", conn)

# Close the database connection
# conn.close()

# df.head()

# df.shape

# %% [markdown]
# #### There were over a half a million reviews in the original db (that had over 300 MB) so in order to be able to upload the file to Github I am scaling down this dataset. The big file is added to .gitignore.
#
# ### Scaling down to 5000 results and saving to database_smaller.sqlite

# %%
# df = df.head(5000)
# df.shape
# Save the smaller database as 'database_smaller.sqlite' in the same folder
# smaller_conn = sqlite3.connect("database\\database_smaller.sqlite")
# df.to_sql("Reviews", smaller_conn, if_exists="replace", index=False)
# smaller_conn.close()

# %%
# Import necessary module
import sqlite3

conn = sqlite3.connect("database\\database_smaller.sqlite")

# Query the sqlite_master table to get the names of all tables
c = conn.cursor()
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = c.fetchall()

# Query the database and load the result into a Pandas DataFrame
df = pd.read_sql_query("SELECT * FROM Reviews", conn)
conn.close()

# %% [markdown]
# #### We will reduce the size of the reviews even further. Let's only consider 1000 rows.

# %%
df = df.head(1000)

# %% [markdown]
# #### Let's conduct a quick EDA to explore the dataset a bit
# Let's start with plotting the grouped star reviews from score variable

# %%
# %matplotlib widget

fig, ax = plt.subplots()

freq = df['Score'].value_counts().sort_values()

ax.bar(freq.index, freq.values,
        width=0.5,
        edgecolor='black')

ax.set_xlabel('Score (stars)')
ax.set_ylabel('Observations')
ax.set_title('Scores from the first 1000 reviews')

# Adding annotations to the plot
for x, y in zip(freq.index, freq.values):
    ax.annotate(str(int(y)), xy=(x, y+10), ha='center', fontsize=12)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## NLPK basics. We introduce the NLPK package to analyze the words

# %%
# Basic example
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
# We need to download the packages below in order to use the word_tokenize, pos_tag and other nltk functions.

import nltk.data
nltk.download('punkt') # Enables word_tokenize. Found with help of https://www.youtube.com/watch?v=GPeWi_2JL_c
nltk.download('averaged_perceptron_tagger') # Enables pos_tag.
nltk.download('maxent_ne_chunker') #Enables chunk.ne_chunk
nltk.download('words') #Enables chunk.ne_chunk
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\macko\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\macko\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\macko\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\macko\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
# tagging tokens with part-of-speech categories
tagged = nltk.pos_tag(tokens)

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint() # pretty-print
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# ### Step 1. VADER Seniment Scoring
#
# - VADER uses a "bag of words" approach.
# - It does not score combination of words but each word separately to average to a total score
# - SentimentIntensityAnalyzer will be used to get neg/neu/pos scores
# - Stop words are removed ('and', 'the', etc...)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon') # Enables SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\macko\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores('I am very happy')  # Example sentence to see the scores
# Out:
# {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6115}

# %%
sia.polarity_scores('I hate it')
# Out:
# {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %% [markdown]
# Now we know how to use nltk. We now have to run this on the entire dataset.

# %%
# Run polarity evaluation on the entire dataset
# tqdm is a Python library that provides a progress bar for iterators in console-based applications.

from tqdm import tqdm
# %matplotlib widget

results = {}

for i, row in tqdm(df.iterrows(), total=len(df), desc='Processing rows'):
    text = row['Text']
    myid = row['Id']
    results[myid] = sia.polarity_scores(text)
# Out:
# Processing rows: 100%|██████████| 1000/1000 [00:00<00:00, 2039.17it/s]

# %%
df_results = pd.DataFrame.from_dict(results)

# %%
df_results = df_results.T
df_results
# Out:
#         neg    neu    pos  compound
# 1     0.000  0.695  0.305    0.9441
# 2     0.138  0.862  0.000   -0.5664
# 3     0.091  0.754  0.155    0.8265
# 4     0.000  1.000  0.000    0.0000
# 5     0.000  0.552  0.448    0.9468
# ...     ...    ...    ...       ...
# 996   0.026  0.721  0.253    0.9788
# 997   0.000  0.786  0.214    0.9309
# 998   0.000  0.673  0.327    0.9634
# 999   0.063  0.874  0.062   -0.0129
# 1000  0.027  0.939  0.034   -0.1027
#
# [1000 rows x 4 columns]

# %%
df_results = df_results.reset_index().rename(columns={'index':'Id'})
df_results.head()
# Out:
#    Id    neg    neu    pos  compound
# 0   1  0.000  0.695  0.305    0.9441
# 1   2  0.138  0.862  0.000   -0.5664
# 2   3  0.091  0.754  0.155    0.8265
# 3   4  0.000  1.000  0.000    0.0000
# 4   5  0.000  0.552  0.448    0.9468

# %%
print(df.shape, df_results.shape)
print(df.columns, df_results.columns)
# Out:
# (1000, 10) (1000, 5)
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object') Index(['Id', 'neg', 'neu', 'pos', 'compound'], dtype='object')

# %%
df_results = df_results.merge(df, how='left')
df_results.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ### Plotting 3 polarity scores (negative, neutral and positive) vs Star-score

# %%
# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, figsize = (10,4))

sns.barplot(x='Score', y='neg', data=df_results, ax=ax0)
sns.barplot(x='Score', y='neu', data=df_results, ax=ax1)
sns.barplot(x='Score', y='pos', data=df_results, ax=ax2)

ax0.set_title('Negative')
ax1.set_title('Neutral')
ax2.set_title('Positive')

ax0.set(ylabel=None)
ax1.set(ylabel=None)
ax2.set(ylabel=None)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Plotting compound polarity score vs Star-score

# %%
ax_compound = sns.catplot(x='Score', y='compound', data=df_results, kind='bar')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Step 3. Roberta Pretrained Model (Huggingface)
#
# - Model trained on a large corpus of data
# - Transformer model will account for both single words, combinations of words, and context

# %%
# pip install transformers
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
# pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment" # Provided by huggingface (already pre-trained)
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Downloading (…)"tf_model.h5";:   0%|          | 0.00/501M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:441, in HTTPResponse._error_catcher(self)
#     440 try:
# --> 441     yield
#     443 except SocketTimeout:
#     444     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     445     # there is yet no clean way to get at it from this context.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:522, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     521 cache_content = False
# --> 522 data = self._fp.read(amt) if not fp_closed else b""
#     523 if (
#     524     amt != 0 and not data
#     525 ):  # Platform-specific: Buggy versions of Python.
#    (...)
#     531     # not properly close the connection in all cases. There is
#     532     # no harm in redundantly calling close.
#
# File c:\Program Files\Python310\lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#
# File c:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Program Files\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Program Files\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\models.py:760, in Response.iter_content.<locals>.generate()
#     759 try:
# --> 760     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761         yield chunk
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:579, in HTTPResponse.stream(self, amt, decode_content)
#     578 while not is_fp_closed(self._fp):
# --> 579     data = self.read(amt=amt, decode_content=decode_content)
#     581     if data:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:515, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     513 fp_closed = getattr(self._fp, "closed", False)
# --> 515 with self._error_catcher():
#     516     if amt is None:
#     517         # cStringIO doesn't like amt=None
#
# File c:\Program Files\Python310\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:446, in HTTPResponse._error_catcher(self)
#     443 except SocketTimeout:
#     444     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     445     # there is yet no clean way to get at it from this context.
# --> 446     raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     448 except BaseSSLError as e:
#     449     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# c:\Users\macko\github\data-science-python\other-data-science-projects\00_sentiment_analysis\sentiment-analysis-vader-roberta-hug.ipynb Cell 37 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/macko/github/data-science-python/other-data-science-projects/00_sentiment_analysis/sentiment-analysis-vader-roberta-hug.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> MODEL = f"cardiffnlp/twitter-roberta-base-sentiment" # Provided by huggingface (already pre-trained)
#       <a href='vscode-notebook-cell:/c%3A/Users/macko/github/data-science-python/other-data-science-projects/00_sentiment_analysis/sentiment-analysis-vader-roberta-hug.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> tokenizer = AutoTokenizer.from_pretrained(MODEL)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/macko/github/data-science-python/other-data-science-projects/00_sentiment_analysis/sentiment-analysis-vader-roberta-hug.ipynb#X51sZmlsZQ%3D%3D?line=3'>4</a> model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\auto\auto_factory.py:464, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     462 elif type(config) in cls._model_mapping.keys():
#     463     model_class = _get_model_class(config, cls._model_mapping)
# --> 464     return model_class.from_pretrained(
#     465         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     466     )
#     467 raise ValueError(
#     468     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     469     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     470 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\modeling_tf_utils.py:2626, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2611 try:
#    2612     # Load from URL or cache if already cached
#    2613     cached_file_kwargs = dict(
#    2614         cache_dir=cache_dir,
#    2615         force_download=force_download,
#    (...)
#    2624         _commit_hash=commit_hash,
#    2625     )
# -> 2626     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    2628     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    2629     # result when internet is up, the repo and revision exist, but the file does not.
#    2630     if resolved_archive_file is None and filename == SAFE_WEIGHTS_NAME:
#    2631         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\utils\hub.py:409, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     406 user_agent = http_user_agent(user_agent)
#     407 try:
#     408     # Load from URL or cache if already cached
# --> 409     resolved_file = hf_hub_download(
#     410         path_or_repo_id,
#     411         filename,
#     412         subfolder=None if len(subfolder) == 0 else subfolder,
#     413         revision=revision,
#     414         cache_dir=cache_dir,
#     415         user_agent=user_agent,
#     416         force_download=force_download,
#     417         proxies=proxies,
#     418         resume_download=resume_download,
#     419         use_auth_token=use_auth_token,
#     420         local_files_only=local_files_only,
#     421     )
#     423 except RepositoryNotFoundError:
#     424     raise EnvironmentError(
#     425         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     426         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     427         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     428         "`huggingface-cli login` and pass `use_auth_token=True`."
#     429     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_validators.py:124, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     119 if check_use_auth_token:
#     120     kwargs = smoothly_deprecate_use_auth_token(
#     121         fn_name=fn.__name__, has_token=has_token, kwargs=kwargs
#     122     )
# --> 124 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:1283, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1280 with temp_file_manager() as temp_file:
#    1281     logger.info("downloading %s to %s", url, temp_file.name)
# -> 1283     http_get(
#    1284         url_to_download,
#    1285         temp_file,
#    1286         proxies=proxies,
#    1287         resume_size=resume_size,
#    1288         headers=headers,
#    1289     )
#    1291 logger.info("storing %s in cache at %s", url, blob_path)
#    1292 _chmod_and_replace(temp_file.name, blob_path)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:530, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     520     displayed_name = content_disposition.split("filename=")[-1]
#     522 progress = tqdm(
#     523     unit="B",
#     524     unit_scale=True,
#    (...)
#     528     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     529 )
# --> 530 for chunk in r.iter_content(chunk_size=10 * 1024 * 1024):
#     531     if chunk:  # filter out keep-alive new chunks
#     532         progress.update(len(chunk))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\models.py:767, in Response.iter_content.<locals>.generate()
#     765         raise ContentDecodingError(e)
#     766     except ReadTimeoutError as e:
# --> 767         raise ConnectionError(e)
#     768 else:
#     769     # Standard file-like object.
#     770     while True:
#
# ConnectionError: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Read timed out.
