# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get("https://bank.gov.ua/en/markets/exchangerates")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Official Exchange Rates
#   </title>
#   <meta content="index,follow" name="robots"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <!-- SEO meta -->
#   <link href="https://bank.gov.ua/en/markets/exchangerates" hreflang="en" rel="alternate"/>
#   <link href="https://bank.gov.ua/ua/markets/exchangerates" hreflang="uk" rel="alternate"/>
#   <link href="https://bank.gov.ua/ua/markets/exchangerates" rel="canonical">
#    <!-- Open Graph Protocol -->
#    <meta content="Official Exchange Rates" property="og:title">
#     <meta content="National Bank of Ukraine" property="og:site_name">
#      <meta content="https://bank.gov.ua/en/markets/exchangerates" property="og:url">
#       <meta content="website" property="og:type"/>
# ...

# %%
period_name = soup.find('span', id ='exchangeDate').get_text()
print(period_name)
# Out:
# 27.01.2023

# %%
list = []
for x in table.find_all('tr'):
    data = [pn.get_text() for pn in x.select("td")]
    list.append(data)

# %%
us_dollar = list[8]
us_dollar.append(period_name)
us_dollar
# Out:
# ['840',
#  'USD',
#  '1',
#  '\n\n                    US Dollar                   \n',
#  '36.5686',
#  '27.01.2023']

# %%
df = pd.DataFrame.from_dict({
    'Date': [us_dollar[5]],
    'Currency': [us_dollar[1]],
    'Rate': [us_dollar[4]]
})
df['Rate'] = df['Rate'].astype(float)
print(df)
# Out:
#          Date Currency     Rate
# 0  27.01.2023      USD  36.5686

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1 non-null      object
#  1   Currency  1 non-null      object
#  2   Rate      1 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 152.0+ bytes
