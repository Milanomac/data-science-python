# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Original website: https://nationalbanken.statistikbank.dk/nbf/99541
# The html code above contained a frameset. It is used to inform the browser of the division of the screen into different split windows, 
# and prohibits any content inside the body associated with a page. I found the link below within the frameset

page = requests.get("https://nationalbanken.statistikbank.dk/statbank5a/selectvarval/saveselections.asp?MainTable=DNRENTD&PLanguage=0&TableStyle=&Buttons=5&PXSId=99541&IQY=&TC=&ST=ST&rvar0=&rvar1=&rvar2=&rvar3=&rvar4=&rvar5=&rvar6=&rvar7=&rvar8=&rvar9=&rvar10=&rvar11=&rvar12=&rvar13=&rvar14=")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" >
# <html lang="da">
#  <head>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Rentesatser og aktieindeks (dagsobservationer) efter instrument, land og opgørelsesmetode - Nationalbankens Statistikbank - data og tal
#   </title>
#   <link href="//nationalbanken.statistikbank.dk/statbank5a/Site/9/favorite.ico" rel="shortcut icon"/>
#   <script src="../jQuery/js/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <link href="../jQuery/css/default/jquery-ui-1.12.1.min.css" rel="stylesheet" type="text/css">
#    <script src="../jQuery/js/jquery-ui-1.12.1.min.js" type="text/javascript">
#    </script>
#    <link href="../site/StatBank9.css?rev2022-1" rel="stylesheet" type="text/css"/>
#    <script src="../site/9/topmenu.js?rev2021-2" type="text/javascript">
#    </script>
#    <script src="../site/9/webstat.js?rev2021-2" type="text/javascript">
#    </script>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   </link>
#  </head>
#  <body>
#   <a class="skipToContent" href="#mainContent" name="top">
#    Gå til sidens indhold
#   </a>
#   <script type="text/javascript">
#    //Insert texts for use in JavaScript function in correct language (see PTda.asp)
# var logonconfirm1 = 'Du skal logge på for at udtrække mere end ';
# var logonconfirm2 = ' tal pr. tabel. Vil du logge på?';
# var gstalert1 = 'Du kan maksimalt udtrække ';
# var gstalert2 = ' tal pr. tabel';
# var peralert = 'Visning af tabeller kræver at, du\nhar foretaget et valg i listen med tid.\n\nVælg en værdi og prøv igen.';
# var valuealert = 'Vælg en eller flere værdier fra ';
# var mapalert = 'Kort kan kun vises for områdefordelte statistikker';
# var undosort = 'Fortryd sortering';
#
# function showspan()	{
# gettingdata.style.visibility="visible";
# }
#
# function autologon(form1)	{
# 	var al = document.forms[form1].elements['AutoLogon'].checked;
# 	if (al)
# 	    //window.open('../Help/autologon.asp?Planguage=0','autologon','width=450,height=510,resizable=1,scrollbars=auto');
# 	    var div = $('<div title="Autologon" class="conceptcontent"></div>').appendTo('body'),
#             url = '../Help/autologon.asp?Planguage=0';
#             div.load(url, function () { $(this).dialog({ width: 500 }) });
# }
#
# function showgraph(lstnr) {
# if (lstnr == 7) {
# index = lstnr;
# }
# else {
# index = document.graphics.graphtype.selectedIndex;
# }
# para = document.graphics.graphtype.options[index].value;
#   if(para == 'graferror') {
#   alert(mapalert);
#   }
#   else {
#       window.open(para,'_blank','width=950,height=510,resizable=1,scrollbars=1');
#   }
# }
#
# function showpxsgraph(fil) {
# para = fil;
# window.open(para,'Diagram','width=950,height=500,resizable=1');
# }
#
# function showdiv(i,j) {
#   rediger.varno.value = i;
#   rediger.vartext.value = j;
#   vartitle.value = j;
#   scr1 = window.document.body.scrollTop;
#   scr2 = window.document.body.scrollLeft;
#   str1 = scr1 + window.event.clientY;
#   str2 = scr2 + window.event.clientX;
#   div1.style.top = str1;
#   div1.style.left = str2;
#   div1.style.visibility = "visible"
# }
#
# function hidediv(i,j)	{
#   rediger.varno.value = "";
#   rediger.vartext.value = "";
#   div1.style.visibility = "hidden";
# }
#
# function calculate(i)	{
#   rediger.varno.value = $('#editorcalc').contents().find('#varno').val();
#   rediger.vartext.value = $('#editorcalc').contents().find('#vartosum').val();
#   rediger.valstring.value = $('#editorcalc').contents().find('#valtosum').val();
#   rediger.newvaltext.value = $('#editorcalc').contents().find('#newvaltext').val();
#   rediger.inclexcl.value = $('#editorcalc').contents().find('#inclexcl').val();
#   rediger.calconst.value = $('#editorcalc').contents().find('#calconst').val();
#   rediger.parmorder.value = $('#editorcalc').contents().find('#parmorder').val();
#   menusubmit(i);
# }
#
# function menusubmit(i)  {
#   rediger.altpivot.value= i;
#   document.rediger.submit();
#   showspan();
# }
#
# function bookmarkme(i)	{
#   url = "http://www." + i;
#   pres = i;
#   if (document.all)
#   window.external.AddFavorite(url,pres)
# }
#
# function help(fil) {
# 	window.open(fil,'Helps','width=800,height=600,resizable=1,toolbar=yes,toolbar=0');
# }
#
# function videoguide(url) {
# 	window.open(url,'Guide','width=1000,height=650,resizable=1,toolbar=yes,toolbar=0');
# }
#
# function servertimer()
# {
# 	if (hour > 24)
# 		hour = '00';
#
# 	if (min < 10 && min != '00')
# 		dismin = '0' + min;
# 	else
# 		dismin = min;
#
# 	dissec = (sec < 10 ? sec = '0' + sec : sec);
#
# 	document.getElementById('servertime').innerHTML = hour + ":" + dismin + ":" + dissec;
#
# 	if (sec < 59)
# 		sec++;
# 	else
# 	{
# 		sec = '0';
# 		min++;
# 		if (min > 59)
# 		{
# 			min = '00';
# 			hour++;
# 		}
# 	}
#
# 	window.setTimeout('servertimer()', 1000);
# }
#
# function logOffConfirm()
# {
# 	time = new Date();
#
# 	answer = confirm('Automatisk pålogning vil blive deaktiveret.\n\nØnsker du at logge af?');
#
# 	try
# 	{
# 		elapsedSeconds = Math.floor((new Date() - time) / 1000);
# 		sec = sec * 1 + elapsedSeconds;
#
# 		min = min * 1 + Math.floor(sec / 60);
# 		sec = sec % 60;
#
# 		hour = hour * 1 + Math.floor(min / 60);
# 		min = min % 60;
#
# 		hour = hour % 24;
# 	}
# 	catch(exception)
# 	{}
#
# 	return answer;
# }
#
# //
# //rettet
# function createCookie(name,value,days)
# {
# 	if (days)
# 	{
# 		var date = new Date();
# 		date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
# 		var expires = '; expires=' + date.toGMTString();
# 	}
# 	else
# 		var expires = '';
#
# 	document.cookie = name + ' = ' + value + expires + '; path=/';
# }
#
# //
# function readCookie(name) {
# 	var nameEQ = name + "=";
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 		var c = ca[i];
# 		while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 		if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# 	}
# 	return null;
# }
#
# //
# function eraseCookie(name) {
# 	createCookie(name,"",-1);
# }
#
# function InternetExplorer()
# {
# 	if ((navigator.appVersion.indexOf("MSIE") != -1) && (navigator.appVersion.indexOf("Macintosh") == -1))
# 		return true;
# 	else
# 		return false;
# }
#
# function FrameDiv(titleInnerText, innerHTML, className, closeImageUrl)
# {
# 	this.removed = false;
# 	this.o = this;
#
# 	if (!document.body.addEventListener)
# 	{
# 		document.body.addEventListener =
# 			function(eventName, functionObject)
# 			{
# 				if (typeof eval('FrameDiv.oldBodyOn' + eventName) == 'undefined')
# 				{
# 					eval('FrameDiv.oldBodyOn' + eventName + ' = (document.body.on' + eventName + ' ? document.body.on' + eventName + ' : function() {})');
# 					eval('document.body.on' + eventName + ' = function() { FrameDiv.oldBodyOn' + eventName + '(); functionObject() }');
# 				}
# 			}
# 	}
#
# 	if (FrameDiv.zIndex == undefined)
# 		FrameDiv.zIndex = 1000;
# 	else
# 		FrameDiv.zIndex++;
#
# 	FrameDiv.CurrentFrame = null;
# 	FrameDiv.CurrentDiv = null;
#
# 	this.setInnerHTML =
# 		function(innerHTML)
# 		{
# 			bodyDiv.innerHTML = innerHTML;
# 		}
#
# 	this.getBodyDiv =
# 		function()
# 		{
# 			return bodyDiv;
# 		}
#
# 	this.moveTo =
# 	    function(x, y)
# 	    {
# 	        frame.style.left = x;
# 	        div.style.left = x;
#
# 	        frame.style.top = y;
# 	        div.style.top = y;
# 	    }
#
#     this.getTop =
#         function()
#         {
#             return div.offsetTop;
#         }
#
# 	this.setClassName =
# 		function(className)
# 		{
# 			frame.style.zIndex = ++FrameDiv.zIndex;
# 			div.style.zIndex = ++FrameDiv.zIndex;
#
# 			div.className = className;
# 			div.style.margin = 0;
# 			div.style.padding = 0;
# 			div.style.position = 'absolute';
#
# 			table.border = 0;
# 			table.cellSpacing = 0;
#
# 			titleTd.className = className;
# 			titleTd.style.border = 'none';
# 			titleTd.style.height = 1;
#
# 			luk.style.position = 'absolute';
# 			luk.style.top = 2;
# 			luk.style.right = 2;
#
# 			bodyTd.colSpan = 2;
#
# 			bodyDiv.className = className;
# 			bodyDiv.style.border = 'none';
# 			bodyDiv.style.overflow = 'auto';
#
# 			div.style.height = table.offsetHeight;
# 			div.style.width = table.offsetWidth;
#
# 			frame.className = className;
# 			frame.style.position = 'absolute';
# 			frame.style.top = div.offsetTop - 1;
# 			frame.style.left = div.offsetLeft - 1;
# 			frame.style.width = div.offsetWidth + 2;
# 			frame.style.height = div.offsetHeight + 2;
# 			frame.style.border = '';
# 		}
#
# 	this.remove =
# 		function()
# 		{
# 			this.o.removed = true;
#
# 			for (var i = 0; i < div.getElementsByTagName('embed').length; i++)
# 				if (typeof div.getElementsByTagName('embed')[i].stop != 'undefined')
# 					div.getElementsByTagName('embed')[i].stop();
#
# 			document.body.removeChild(div);
# 			if (microsoft())
# 				document.body.removeChild(frame);
# 		}
#
# 	this.append =
# 		function()
# 		{
# 			div.style.visibility = 'hidden';
# 			div.style.filter = 'progid:DXImageTransform.Microsoft.Fade(duration=.3)';
#
# 			if (microsoft())
# 				document.body.appendChild(frame);
# 			document.body.appendChild(div);
#
# 			if (microsoft())
# 			{
# 			    try
# 			    {
# 				    div.filters[0].apply();
# 				    div.filters[0].play();
# 				}
# 				catch(exception)
# 				{}
# 			}
# 			else
# 			{
# 				fadeIn(div);
# 			}
# 			div.style.visibility = 'visible';
# 		}
#
# 	var frame = document.createElement('iframe');
# 	var div = document.createElement('div');
# 		div.parent = frame;
# 		var table = document.createElement('table');
# 		var tbody = document.createElement('tbody');
# 			var headTr = document.createElement('tr');
# 				var titleTd = document.createElement('td');
# 					titleTd.parent = div;
# 					var luk = document.createElement('img');
# 			var bodyTr = document.createElement('tr');
# 				var bodyTd = document.createElement('td');
# 					var bodyDiv = document.createElement('div');
#
# 	titleTd.appendChild(luk);
# 	headTr.appendChild(titleTd);
#
# 	bodyTd.appendChild(bodyDiv);
# 	bodyTr.appendChild(bodyTd);
#
# 	tbody.appendChild(headTr);
# 	tbody.appendChild(bodyTr);
#
# 	table.appendChild(tbody);
#
# 	div.appendChild(table);
#
# 	var image = new Image();
# 	image.src = closeImageUrl;
#
# 	luk.src = closeImageUrl;
#
# 	this.title = document.createTextNode(titleInnerText);
# 	titleTd.appendChild(this.title);
#
# 	this.setTitle =
# 	    function(t)
# 	    {
# 	        this.title.innerText = t;
# 	    }
#
# 	this.setInnerHTML(innerHTML);
#
# 	this.append();
# 	this.setClassName(className);
#
# 	div.onmousedown =
# 		function()
# 		{
# 			frame.style.zIndex = ++FrameDiv.zIndex;
# 			div.style.zIndex = ++FrameDiv.zIndex;
# 		}
#
# 	luk.o = this;
# 	luk.onmouseup = this.remove;
#
# 	var yDiff, xDiff;
# 	titleTd.onmousedown =
# 		function(eventArg)
# 		{
# 			if (eventArg)
# 				event = eventArg;
#
# 			if (event.srcElement == luk || event.target == luk)
# 				return;
#
# 			FrameDiv.CurrentDiv = this.parent;
# 			FrameDiv.CurrentFrame = this.parent.parent;
#
# 			var x = (event.x ? event.x : event.pageX);
# 			var y = (event.y ? event.y : event.pageY);
#
# 			FrameDiv.yDiff = y - div.offsetTop;
# 			FrameDiv.xDiff = x - div.offsetLeft;
# 		}
#
# 	if (FrameDiv.eventsSet != true)
# 	{
# 		FrameDiv.eventsSet = true;
#
# 		document.body.addEventListener('mousemove',
# 			function(eventArg)
# 			{
# 				if (eventArg)
# 					event = eventArg;
#
# 				if (FrameDiv.CurrentFrame == null)
# 					return;
#
# 				var x = (event.x ? event.x : event.pageX);
# 				var y = (event.y ? event.y : event.pageY);
#
# 				FrameDiv.CurrentDiv.style.top = y - FrameDiv.yDiff;
# 				FrameDiv.CurrentDiv.style.left = x - FrameDiv.xDiff;
#
# 				FrameDiv.CurrentFrame.style.top = y - FrameDiv.yDiff - 1;
# 				FrameDiv.CurrentFrame.style.left = x - FrameDiv.xDiff - 1;
# 			},
# 			false);
#
# 		document.body.addEventListener('mouseup',
# 			function()
# 			{
# 				FrameDiv.CurrentFrame = null;
# 				FrameDiv.CurrentDiv = null;
# 			},
# 			false);
# 	}
# }
#
# function microsoft()
# {
# 	return (navigator.appName.indexOf('Microsoft') > -1);
# }
#
# function safari()
# {
# 	return (navigator.appVersion.indexOf('Safari') > -1);
# }
#
# var elem, opac;
# function fadeIn(element, opacity)
# {
# 	if (opacity == null)
# 		opacity = 0;
#
# 	element.style.opacity = opacity;
#
# 	if (opacity >= 1)
# 	{
# 		return;
# 	}
# 	else
# 	{
# 		opacity += .1;
# 		elem = element;
# 		opac = opacity;
# 		setTimeout('fadeIn(elem, opac);', 10);
# 	}
# }
#
# function colorRange(event, color) {
# 	var e = (event.srcElement ? event.srcElement : event.target);
# 	while (e.nodeName != 'TR' && e.parentNode) e = e.parentNode;
# 	if (e.nodeName == 'TR') { e.className = (color ? 'hovertr' : 'mytablestr');}
# }
#
# function MainConcepts(mt) {
# 	$('.conceptcontent').remove();
# 	var url = "../Common/getConcepts.asp?maintable=" + mt + "&Planguage=0";
# 	var div = $('<div title="Begreber" class="conceptcontent"></div>');
# 	$('body').append(div);
# 	div.load(url,function() {$(this).dialog({width:500})});
# }
#
# function ShowConcepts(vs,tit) {
#     $('.conceptcontent').remove();
# 	var url = "../Common/getConcepts.asp?valueset=" + vs + "&Planguage=0";
# 	var div = $('<div title="Begreber" class="conceptcontent"></div>');
# 	$('body').append(div);
# 	div.load(url, function() {$(this).dialog({width:500});changevaluetxt(tit)});
# }
#
# function changevaluetxt(tit) {
# 	$('#valuesetid').html(tit);
# 	$('#variabelid').html(tit);
# 	tit = tit.replace("/", "_Ss_")
# 	tit = tit.replace("ø", "_oe_")
# 	tit = tit.replace("Ø", "_OE_")
# 	tit = tit.replace("æ", "_ae_")
# 	tit = tit.replace("Æ", "_AE_")
# 	tit = tit.replace("å", "_aa_")
# 	tit = tit.replace("Å", "_AA_")
# 	var url = "/" + '"' + tit + '"';
# 	$('#variabelurl').attr('href',url);
# }
#
# function ShowTableInfo(mt) {
# 	$('.infodialog').remove();
# 	var url = "../SelectVarval/define.asp?Tabstrip=INFO&maintable=" + mt + "&Planguage=0";
# 	$.get(
# 		url,
# 		function (data)
# 		{
# 			$('<div title="Information: '+ mt +'" class="infodialog"></div>').html($(data).find('.infotbl')).appendTo('body').dialog({width:600});
# 		}
# 	);
# }
#
# function epost(user, domain, querystring)
# {
# 	var t = user + qwerty(true) + domain;
#
# 	if (querystring.length > 0)
# 		t += '?' + querystring;
#
# 	return t;
# }
#
# function qwerty(qwerty)
# {
# 	if (qwerty)
# 		return '@';
# 	else
# 		return '';
# }
#
# function adjustFootnote()
# {
# 	$('.pxtable .footnote').each(
# 		function()
# 		{
# 			var br = $(this).html().toLowerCase().indexOf('&nbsp;');
#
# 			if (br > -1)
# 			{
# 				var hide = $(this).html().substring(br + 6);
#
# 				$(this).html($(this).html().substring(0, br));
#
# 				$('<span class="footnoteToggle"/>').appendTo($(this)).append(
# 					'<span class="toggle hide">' + hide + '</span>',
# 					'<span class="flnote handle toggle"><br/>Læs mere ... &raquo;</span>',
# 					'<span class="flnote handle toggle hide"><br/>Læs mere ... &laquo;</span>'
# 				).find('.handle').click(
# 					function()
# 					{
# 						$(this).siblings('.toggle').addBack().toggle();
# 					}
# 				);
# 			}
# 		}
# 	);
# }
#   </script>
#   <span class="snail" id="gettingdata">
#    Henter data ...
#    <img alt="" role="presentation" src="../Site/9/larve.gif"/>
#    ... vent et øjeblik
#   </span>
#   <table background="../Site/9/top_NAT.gif?rev2022-2" class="toptbl">
#    <tr>
#     <td class="toplogotd" onclick="javascript:window.open('http://www.nationalbanken.dk');">
#      <table class="toplogotbl">
#       <tr>
#        <td>
#        </td>
#       </tr>
#      </table>
#     </td>
#     <td class="topcrumstd" valign="bottom">
#      <table class="topcrumstbl">
#       <tr>
#        <td>
#         <img alt="" role="presentation" src="../Site/9/hjem.gif"/>
#         <a class="topcrumslink" href="../SelectTable/Omrade0.asp?PLanguage=0" onclick="javascript:showspan()" title="Startsiden">
#          Nationalbankens Statistikbank
#         </a>
#         <a class="topcrumslink" href="../SelectTable/Omrade0.asp?SubjectCode=901&amp;ShowNews=OFF&amp;PLanguage=0" onclick="javascript:showspan()" title="">
#          Rentesatser
#         </a>
#         <a class="topcrumslink" href="../SelectVarVal/Define.asp?Maintable=DNRENTD&amp;PLanguage=0" onclick="javascript:showspan()" title="">
#          Vælg fra tabellen
#          <span class="mainref">
#           DNRENTD
#          </span>
#         </a>
#        </td>
#       </tr>
#      </table>
#     </td>
#     <td align="right" class="topmenubartd" valign="bottom">
#      <table class="topmenubartbl">
#       <tr>
#        <td>
#         <img alt="" role="presentation" src="../Site/1/sep.gif"/>
#         <a class="topmenulink" href="../SelectTable/Omrade0.asp?logon=yes&amp;PLanguage=0&amp;SubjectCode=901&amp;MainTable=DNRENTD&amp;pxsid=99541&amp;TC=" title="Log på">
#          <img alt="" role="presentation" src="../Site/9/lock.gif"/>
#          Log på
#         </a>
#         <img alt="" role="presentation" src="../Site/1/sep.gif"/>
#         <a class="topmenulink" href="../SelectVarVal/Define.asp?Maintable=DNRENTD&amp;Pxsid=99541&amp;ST=ST&amp;PLanguage=1" title="English">
#          <img alt="" role="presentation" src="../Site/9/English.gif"/>
#         </a>
#         <img alt="" role="presentation" src="../Site/1/sep.gif"/>
#         <a class="topmenulink" href="javascript:help('../Help/Help.asp?menuname=SaveSelection&amp;PLanguage=0');" title="Hjælp">
#          <img alt="" role="presentation" src="../Site/9/spg12.gif"/>
#          Hjælp
#         </a>
#         <img alt="" role="presentation" src="../Site/1/sep.gif"/>
#        </td>
#       </tr>
#      </table>
#     </td>
#     <td class="topsearchtd">
#      <form action="../search2003/searchresult.asp?place=statbank" method="post" name="content">
#       <table class="searchtbl">
#        <tr>
#         <td>
#          <input autocomplete="off" class="searchinp" maxlength="100" name="searchtext" size="20" type="search" value=""/>
#         </td>
#         <td>
#          <input class="searchbtn" id="submit1" name="submit1" onclick="javascript:showspan()" type="submit" value="SØG"/>
#          <input name="start" type="hidden" value="1"/>
#          <input name="kunvarde" type="hidden" value="-1"/>
#          <input name="form" type="hidden" value="-1"/>
#          <input name="PLanguage" type="hidden" value="0"/>
#          <input name="searchin" type="hidden" value=""/>
#         </td>
#        </tr>
#       </table>
#       <input name="as_sfid" type="hidden" value="AAAAAAVHVHJKQMemCFBac2fRYbLznrNb3C9bgqijo6sgmWrQTxTOIQYSGceFPBY2HKL5cih_Nsc6mt9Ll4bMIYQjFuABdmzK_dvYhjBQffB2319TuXyIfL-6aHI6pdf7-Kn03_Ijsbd5iGpXMnx9N0eXZ6WxABjh7qOOb4f1kdWyRFxAEg==">
#        <input name="as_fid" type="hidden" value="402bfb4f3afc357f0095b0d7052d1b8181ba13e5"/>
#       </input>
#      </form>
#     </td>
#    </tr>
#   </table>
#   <table class="maintitle2tbl">
#    <tr>
#     <td aria-level="1" class="maintitle2bar" role="heading">
#      <font class="mainref">
#       DNRENTD:
#      </font>
#      Rentesatser og aktieindeks (dagsobservationer) efter instrument, land og opgørelsesmetode
#     </td>
#    </tr>
#   </table>
#   <a name="mainContent">
#   </a>
#   <div class="pivotcontainer">
#    <table cellspacing="0" class="tablemenu">
#     <tr class="tablemenutr">
#      <td class="tablemenutd1">
#       Åbn / gem som...
#      </td>
#      <td>
#      </td>
#      <td class="tablemenutd1">
#       Rediger tabel
#      </td>
#      <td>
#      </td>
#      <td class="tablemenutd1">
#       Grafisk præsentation
#      </td>
#     </tr>
#     <tr>
#      <td>
#       <form action="../selectout/ready.asp?PLanguage=0&amp;pxfile=D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051.px&amp;outfile=D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051&amp;queryfile=9954159338065051&amp;Pxsid=99541" id="ready" method="post" name="ready">
#        <tr>
#         <td valign="top">
#          <select aria-label="Åbn / gem som..." name="fileformatid" onchange="submit();">
#           <option value="1">
#            PC-AXIS (*.px)
#           </option>
#           <option value="20">
#            Excel (*.xlsx)
#           </option>
#           <option selected="" value="2">
#            Excel (*.xls)
#           </option>
#           <!--<OPTION VALUE="16" >PXML (*.xml)</OPTION>-->
#           <option value="4">
#            DBase (*.dbf)
#           </option>
#           <option value="5">
#            DBase som rækker (*.dbf)
#           </option>
#           <option value="9">
#            SAS program (*.sas)
#           </option>
#           <option value="6">
#            Semikolonsepareret (*.csv)
#           </option>
#           <option value="7">
#            Tabulatorsepareret (*.csv)
#           </option>
#           <option value="8">
#            Kommasepareret (*.csv)
#           </option>
#           <option value="10">
#            Matrix (*.csv)
#           </option>
#           <option value="3">
#            Tekst m. layout (*.txt)
#           </option>
#           <option value="11">
#            Tekst matrix (*.txt)
#           </option>
#           <option value="12">
#            Tidsserie t. Aremos (*.tsd)
#           </option>
#           <option value="13">
#            Tidsserier batch (*.asb)
#           </option>
#          </select>
#          <input alt="OK" border="0" name="run" src="../Site/9/pilfrem.gif" title="Åbn / gem som..." type="image"/>
#          <table border="0" cellpadding="0" cellspacing="0">
#           <tr>
#            <td>
#             <input id="dbl" name="dbl" title="For Excel, DBase" type="checkbox"/>
#             <font class="signatur" title="For Excel, DBase">
#              Inkl. koder i sep. kolonner
#             </font>
#             <br/>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <input checked="" id="sfn" name="sfn" title="For Excel, DBase" type="checkbox"/>
#             <font class="signatur" title="For Excel, DBase">
#              Inkl. fodnoter mv.
#             </font>
#             <input name="Potsize" type="hidden" value="452"/>
#             <input name="MainTable" type="hidden" value="DNRENTD"/>
#            </td>
#           </tr>
#          </table>
#          <input name="as_sfid" type="hidden" value="AAAAAAU2bRd1DAuIqDeSmtYX00OH8z-gANksUM2cX4Y8O-n8fdTC51WcxvpIvN8EeLFEoXya6QSwW9VjlsSAUh8Zj8-CRnhKT2D8cB_uQI6t4RYl_Rw1MCChR7X3qO72YfFiD_WW3bGdeo0q_Lw0Ft8n3WByaqrk-2q2p7wkGG8wF6txdg==">
#           <input name="as_fid" type="hidden" value="47821afb1b6e9ccaa9a68a107908be43f4bb789e"/>
#          </input>
#         </td>
#        </tr>
#       </form>
#      </td>
#      <td>
#       <hr class="hrspacer"/>
#      </td>
#      <td valign="top">
#       <form action="../Selectout/pivot.asp" method="post" name="rediger">
#        <select aria-label="Rediger tabel" name="pivot" onchange="return subedit(this);">
#         <option value="1">
#          Pivot: Drej med uret
#         </option>
#         <option value="2">
#          Rediger variabelrækkefølgen
#         </option>
#         <option value="0">
#          Valgfri pivot (træk og slip)
#         </option>
#         <option value="3">
#          Fjern nullinier
#         </option>
#         <option value="5">
#          Vis koder og tekster
#         </option>
#         <option value="6">
#          Vis kun koder
#         </option>
#         <option value="7">
#          Vis kun tekster (normal)
#         </option>
#        </select>
#        <input alt="OK" border="0" name="run" onclick="return subedit(this);" src="../Site/9/pilfrem.gif" title="" type="image"/>
#        <input name="pxfile" type="hidden" value="D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051.px"/>
#        <input name="outfile" type="hidden" value="D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051"/>
#        <input name="Queryfile" type="hidden" value="9954159338065051"/>
#        <input name="Pxsid" type="hidden" value="99541"/>
#        <input name="FileformatId" type="hidden" value="2"/>
#        <input name="PLanguage" type="hidden" value="0"/>
#        <input name="MainTable" type="hidden" value="DNRENTD"/>
#        <input name="SubjectArea" type="hidden" value="Rentesatser"/>
#        <input name="SubjectCode" type="hidden" value="901"/>
#        <input name="TC" type="hidden" value=""/>
#        <input name="NullInTable" type="hidden" value=""/>
#        <input name="UseDots" type="hidden" value="True"/>
#        <input name="potsize" type="hidden" value="452"/>
#        <input name="Buttons" type="hidden" value="5"/>
#        <input name="TableStyle" type="hidden" value=""/>
#        <input name="antalvar" type="hidden" value="4"/>
#        <input name="PxSStub" type="hidden" value="land¤opgørelsesmetode¤instrument¤tid"/>
#        <input name="as_sfid" type="hidden" value="AAAAAAUfIWymiOYH16I8AKf72NCJGs5sj3MUBS1g2i4_W6cFc75PLHtAfcxe3tXVChhDs17Vdk0x6F-JfoGuMrfpXHIxlPuvogKurWK8F_EBRJPiGnXxjitJUPj-cLh5XE8CNebwoMN3AYvNyKQhEKrsjI6K5qyiQhEZVPqK92cUsVFa3A==">
#         <input name="as_fid" type="hidden" value="67d2b430195e0b96c85200b1cf3321632dde0d55"/>
#        </input>
#       </form>
#      </td>
#      <td>
#       <hr class="hrspacer"/>
#      </td>
#      <td valign="top">
#       <form action="../Graphics/MakeGraph.asp?onpx=y&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=0&amp;PLanguage=0" method="post" name="graphics">
#        <select aria-label="Grafisk præsentation" name="graphtype" onchange="showgraph();">
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=0&amp;PLanguage=0">
#          Kurvediagram
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=1&amp;PLanguage=0">
#          Søjlediagram
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=2&amp;PLanguage=0">
#          Liggende søjlediagram
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=3&amp;PLanguage=0">
#          Stablede søjler
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=30&amp;PLanguage=0">
#          Søjler og kurver (2 akser)
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=50&amp;PLanguage=0">
#          Befolkningspyramide
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=5&amp;PLanguage=0">
#          Cirkeldiagram
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=8&amp;PLanguage=0">
#          Områdediagram
#         </option>
#         <option value="../Graphics/MakeGraph.asp?interactive=true&amp;menu=y&amp;maintable=DNRENTD&amp;pxfile=9954159338065051.px&amp;gr_type=9&amp;PLanguage=0">
#          Stablet områdediagram
#         </option>
#         <option style="color: gray;" value="graferror">
#          Vis data på landkort
#         </option>
#        </select>
#        <img alt="OK" border="0" onclick="showgraph();" src="../Site/9/pilfrem.gif" style="cursor:pointer;cursor:hand;" title=""/>
#        <input name="as_sfid" type="hidden" value="AAAAAAUP_HsRkmIbjv3IEtsbwwFJg04L5j9BmBm0vXEz1QCdDhuisWnR-5RLx7g6rWJJAdKLsJbpQ3dYJRZcRvGOIhtVat3UrrRAjUdOa59SvrNaFpKrV6ZooMCfhykM5INIOFLEcTPYLb7LGqgOous_lg1_Rkckgd_XYC1hbqnQ7VetwA==">
#         <input name="as_fid" type="hidden" value="36fdfb9c46747101ce1c59bd89ba150f950bc3d5"/>
#        </input>
#       </form>
#      </td>
#      <td>
#       <hr class="hrspacer"/>
#      </td>
#      <td valign="top">
#       <img alt="" class="sortgif" id="sortgif" role="presentation" src="../Site/9/sortdata.gif"/>
#      </td>
#      <td class="sorttd" valign="top">
#       <a class="fl" href="../SelectOut/PxSort.asp?file=9954159338065051&amp;PLanguage=0&amp;MainTable=DNRENTD&amp;MainTablePrestext=Rentesatser og aktieindeks (dagsobservationer)&amp;potsize=452" id="sortdata" target="_new" title="Sorter data">
#        Sorter data
#       </a>
#      </td>
#      <td>
#       <hr class="hrspacer"/>
#      </td>
#      <td valign="top">
#       <img alt="" class="printgif" role="presentation" src="../Site/9/printa.gif"/>
#      </td>
#      <td class="printtd" valign="top">
#       <a class="fl" href="../selectout/print.asp?pxfile=D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051.px&amp;outfile=D:\ftproot\LocalUser\statbank\statbank5a\Temp\9954159338065051&amp;FileformatId=2&amp;Queryfile=9954159338065051&amp;PLanguage=0&amp;MainTable=DNRENTD&amp;MainTablePrestext=Rentesatser og aktieindeks (dagsobservationer) efter instrument, land og opgørelsesmetode&amp;potsize=452&amp;Buttons=5&amp;TableStyle=" target="_new" title="printvenlig">
#        printvenlig
#       </a>
#      </td>
#     </tr>
#    </table>
#    <div class="NBdateConvert">
#     <a id="nb405" onclick="javascript:macroWindow();">
#      Konverter datoformat i Excel
#     </a>
#    </div>
#    <script src="../Site/9/LocalScripts.js">
#    </script>
#    <div id="calcdiv" title="Beregn">
#     <iframe frameborder="0" height="98%" id="editorcalc" marginheight="0" marginwidth="0" scrolling="auto" tabindex="0" width="98%">
#     </iframe>
#    </div>
#    <div id="tableAreaContainer">
#     <div id="tableArea">
#      <table class="pxtable" id="pxtable">
#       <tr>
#        <th class="title" colspan="114">
#         Rentesatser og aktieindeks (dagsobservationer) efter land,
#         <br/>
#         opgørelsesmetode, instrument og tid
#        </th>
#       </tr>
#       <tr>
#        <th class="headfirst" colspan="1" rowspan="1">
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D17
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D18
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D19
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D22
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D23
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D24
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D25
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D26
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D29
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D30
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M08D31
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D01
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D02
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D05
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D06
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D07
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D08
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D09
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D12
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D13
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D14
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D15
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D16
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D19
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D20
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D21
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D22
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D23
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D26
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D27
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D28
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D29
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M09D30
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D03
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D04
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D05
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D06
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D07
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D10
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D11
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D12
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D13
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D14
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D17
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D18
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D19
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D20
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D21
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D24
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D25
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D26
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D27
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D28
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M10D31
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D01
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D02
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D03
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D04
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D07
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D08
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D09
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D10
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D11
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D14
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D15
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D16
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D17
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D18
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D21
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D22
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D23
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D24
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D25
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D28
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D29
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M11D30
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D01
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D02
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D05
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D06
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D07
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D08
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D09
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D12
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D13
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D14
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D15
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D16
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D19
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D20
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D21
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D22
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D23
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D27
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D28
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D29
#        </th>
#        <th class="headfirst" colspan="1">
#         2022M12D30
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D02
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D03
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D04
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D05
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D06
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D09
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D10
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D11
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D12
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D13
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D16
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D17
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D18
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D19
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D20
#        </th>
#        <th class="headfirst" colspan="1">
#         2023M01D23
#        </th>
#       </tr>
#       <tr>
#        <td class="stub1" rowspan="1">
#         DK: Danmark
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#       </tr>
#       <tr>
#        <td class="stub2" rowspan="1">
#         Daglige renter (procent)
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#        <td class="Nn">
#        </td>
#       </tr>
#       <tr>
#        <td class="stub3">
#         Nationalbankens rente - Diskonto (Aug. 1987-)
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,0000
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
#        <td class="No">
#         0,6500
#        </td>
# ...
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,2500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#        <td class="No">
#         1,7500
#        </td>
#       </tr>
#       <tr>
#        <td class="footnote" colspan="114">
#         <br/>
#         Historiske data for afsluttede serier kan findes på Danmarks Nationalbanks
#         <a href="https://www.nationalbanken.dk/da/statistik/find_statistik/Documents/Specifikation%20til%20Nationalbankens%20balance/Arkiv_DNRENTD.csv" target="_new">
#          hjemmeside
#         </a>
#         <br/>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <script>
#     var pivotStub = 'land%A4opg%F8relsesmetode%A4instrument';
# var pivotHeading = 'tid';
# var basket = null;
# var grabbed;
# var pivotWindow = null;
#
# var jobs = new Jobs();
#
# function openPivotWindow()
# {
# 	if (pivotWindow && !pivotWindow.removed)
# 	{
#         placeWindow();
#     }
#     else
#     {
# 	    var fdContents = ajaxGet('../PXSBatchV5/PivotWindow.asp?stub=' + pivotStub + '&heading=' + pivotHeading + '&pxfile=D:\\ftproot\\LocalUser\\statbank\\statbank5a\\Temp\\9954159338065051.px&outfile=D:\\ftproot\\LocalUser\\statbank\\statbank5a\\Temp\\9954159338065051&Pxsid=99541&FileFormatId=0&Queryfile=9954159338065051&PLanguage=0&MainTable=DNRENTD&SubjectArea=Rentesatser&SubjectCode=901&UseDots=True&NullInTable=&potsize=452&pivot=&antalvar=4&PxSStub=land¤opgørelsesmetode¤instrument¤tid&varno=&valstring=&altpivot=&newvaltext=', false);
# 	    pivotWindow = new FrameDiv('     Pivotér tabel', fdContents, 'pivotFrameDiv', '../site/9/luk.gif');
#         placeWindow();
# 	}
# }
#
# function placeWindow()
# {
#     var x = (document.clientWidth ? document.clientWidth : document.body.clientWidth) / 2 - 220;
#
#     var y = (document.clientHeight ? document.clientHeight : document.body.clientHeight) + document.body.scrollTop - 500;
#     if (y > document.getElementById('tableAreaContainer').offsetTop + document.getElementById('tableAreaContainer').offsetHeight)
#         y = document.getElementById('tableAreaContainer').offsetTop + document.getElementById('tableAreaContainer').offsetHeight + 10;
#
#     pivotWindow.moveTo(x, y);
# }
#
# document.body.onmousemove =
# 	function(e)
# 	{
# 	    if (!e)
# 	        e = event;
#
# 		if (basket != null)
# 		{
# 		    basket.style.left = e.clientX + document.body.scrollLeft + 10 + 'px';
# 		    basket.style.top = e.clientY + document.body.scrollTop + 10 + 'px';
# 		}
# 	}
#
# document.body.onmouseup =
# 	function(e)
# 	{
# 	    if (!e)
# 	        e = event;
#
# 		var eventSrcElement = (microsoft() ? e.srcElement : e.target);
#
# 		if (basket != null)
# 		{
#             var divs = document.getElementsByTagName('div');
#             for (var i = 0; i < divs.length; i++)
#                 if (divs[i].className == 'pivotFrameDiv')
#                     divs[i].style.cursor = 'default';
#
# 		    document.body.removeChild(basket);
# 		    basket = null;
#
# 		    if (eventSrcElement == grabbed)
# 			    return;
#
# 		    if (eventSrcElement.className == 'variableBox' || (eventSrcElement.parentNode && eventSrcElement.parentNode.className == 'variableBox'))
# 			    var dropBox = (eventSrcElement.className == 'variableBox' ? eventSrcElement : eventSrcElement.parentNode);
# 		    else
# 			    return;
#
# 		    var tempBox = dropBox.cloneNode(true);
#
# 		    while (tempBox.getElementsByTagName('a').length > 0)
# 			    tempBox.removeChild(tempBox.getElementsByTagName('a')[0]);
#
# 		    if (eventSrcElement.className == 'header')
# 			    tempBox.appendChild(addImageToInnerHTML(grabbed.cloneNode(true)));
# 		    var v = dropBox.getElementsByTagName('a');
# 		    for (var i = 0; i < v.length; i++)
# 		    {
# 			    if (v[i] == eventSrcElement)
# 				    tempBox.appendChild(addImageToInnerHTML(grabbed.cloneNode(true)));
#
# 			    if (v[i] != grabbed)
# 				    tempBox.appendChild(v[i].cloneNode(true));
# 		    }
# 		    if (eventSrcElement.className == 'variableBox')
# 			    tempBox.appendChild(addImageToInnerHTML(grabbed.cloneNode(true)));
#
# 		    grabbed.parentNode.removeChild(grabbed);
# 		    dropBox.innerHTML = tempBox.innerHTML;
# 		    tempBox = null;
#
# 		    //setTimeout('doIt();', 10);
#         }
# 	}
#
# function addImageToInnerHTML(element)
# {
#     return element;
# }
#
# function grab(v, e)
# {
#     if (!e)
#         e = event;
#
#     var divs = document.getElementsByTagName('div');
#     for (var i = 0; i < divs.length; i++)
#         if (divs[i].className == 'pivotFrameDiv')
#             divs[i].style.cursor = 'not-allowed';
#
# 	grabbed = v;
# 	basket = v.cloneNode(true);
# 	basket.className = 'basket';
# 	basket.style.left = e.clientX + document.body.scrollLeft + 10 + 'px';
# 	basket.style.top = e.clientY + document.body.scrollTop + 10 + 'px';
# 	basket.style.zIndex = 2000;
# 	document.body.appendChild(basket);
# }
#
# function doIt()
# {
# 	var boxHeading = document.getElementById('boxHeading');
# 	var boxStub = document.getElementById('boxStub');
#
# 	var t = 0;
#
# 	var stubList = '';
# 	var stubListWords = '';
# 	var elements = boxStub.getElementsByTagName('a');
# 	for (var i = 0; i < elements.length; i++)
# 	{
# 		if (stubList != '')
# 			stubList += ',';
#
# 		if (stubListWords != '')
# 			stubListWords += '¤';
#
# 		stubList += elements[i].id;
# 		stubListWords += (elements[i].innerText ? elements[i].innerText : elements[i].textContent);
#
# 		t++;
# 		elements[i].id = t;
# 	}
#
# 	var headingList = '';
# 	var headingListWords = '';
# 	var elements = boxHeading.getElementsByTagName('a');
# 	for (var i = 0; i < elements.length; i++)
# 	{
# 		if (headingList != '')
# 			headingList += ',';
#
# 		if (headingListWords != '')
# 			headingListWords += '¤';
#
# 		headingList += elements[i].id;
# 		headingListWords += (elements[i].innerText ? elements[i].innerText : elements[i].textContent);
#
# 		t++;
# 		elements[i].id = t;
# 	}
#
# 	pivotStub = escape(stubListWords);
# 	pivotHeading = escape(headingListWords);
#
# 	jobs.addJob('../PXSBatchV5/PivotAjax.asp?stubList=' + stubList + '&headingList=' + headingList + '&pxfile=D:\\ftproot\\LocalUser\\statbank\\statbank5a\\Temp\\9954159338065051.px&outfile=D:\\ftproot\\LocalUser\\statbank\\statbank5a\\Temp\\9954159338065051&Pxsid=99541&FileFormatId=0&Queryfile=9954159338065051&PLanguage=0&MainTable=DNRENTD&SubjectArea=Rentesatser&SubjectCode=901&UseDots=True&NullInTable=&potsize=452&pivot=&antalvar=4&PxSStub=land¤opgørelsesmetode¤instrument¤tid&varno=&valstring=&altpivot=&newvaltext=', true);
# 	jobs.run();
#
# 	pivotWindow.remove();
#
# disableSort(headingList);
# }
#
# function Jobs()
# {
#     this.id = 0;
#     var list = new Array();
#     var running = false;
#
#     this.addJob =
#         function(url, ascr)
#         {
#             list[this.id] = new Job(url, ascr, this.id);
#             this.id++;
#         }
#
#     this.run =
#         function()
#         {
#             if (running)
#                 return;
#
#             running = true;
#
#             jobs.runNextJob();
#         }
#
#     this.runNextJob =
#         function()
#         {
#             var j = this.nextJob();
#
#             if (j == null)
#             {
#                 running = false;
#                 return;
#             }
#
#             if (!j.gettingData)
#                 j.run();
#
#             setTimeout('jobs.runNextJob();', 1000);
#         }
#
#     this.nextJob =
#         function()
#         {
#             for (var i = 0; i < list.length; i++)
#                 if (!list[i].done)
#                 {
#                     return list[i];
#                     break;
#                 }
#
#             return null;
#         }
# }
#
# function Job(url, ascr, id)
# {
#     this.done = false;
#     this.gettingdata = false;
#
#     this.id = id;
#     this.url = url;
#     this.ascr = ascr;
#
#     this.run =
#         function()
#         {
#             if (!document.getElementById('glass'))
#             {
# 		        var tableArea = document.getElementById('tableArea');
#
# 		        var glass = document.createElement('div');
# 		        glass.id = 'glass';
# 		        glass.className = 'coverTable';
# 		        glass.style.position = 'absolute';
# 		        glass.style.left = tableArea.offsetLeft;
# 		        glass.style.top = tableArea.offsetTop;
# 		        glass.style.width = tableArea.offsetWidth + 50;
# 		        glass.style.height = tableArea.offsetHeight + 20;
# 		        document.body.appendChild(glass);
#
# 		        var waitImage = document.createElement('img');
# 		        waitImage.id = 'waitImage';
# 		        waitImage.className = 'ajaxGettingDataImage';
# 		        waitImage.src = '../site/1/loading.gif';
# 		        waitImage.style.top = tableArea.offsetTop;
# 		        waitImage.style.left = document.getElementById('pxtable').offsetLeft;
# 		        document.body.appendChild(waitImage);
# 		    }
#
#             this.gettingData = true;
#             ajaxGet(url, ascr, this);
#         }
# }
#
# function ajaxGet(url, ascr, job)
# {
#     var ajaxReq;
#
#     if (window.XMLHttpRequest)
#     {
# 	    ajaxReq = new XMLHttpRequest();
#     }
#     else if (window.ActiveXObject)
#     {
# 	    try
# 	    {
# 		    ajaxReq = new ActiveXObject("Msxml2.XMLHTTP");
# 	    }
# 	    catch (e1)
# 	    {
# 		    try
# 		    {
# 			    ajaxReq = new ActiveXObject("Microsoft.XMLHTTP");
# 		    }
# 		    catch (e2)
# 		    {
# 			    ajaxReq = false;
# 		    }
# 	    }
#     }
#
# 	if (!ajaxReq) return;
#
#     ajaxReq.open('get', url, ascr);
#
#     if (ascr)
#     {
#         ajaxReq.onreadystatechange = function() { ajaxCallBack(ajaxReq, job); };
# 	    ajaxReq.send('');
# 	}
#     else
#     {
#     	ajaxReq.send('');
#         var data = ajaxReq.responseXML.getElementsByTagName('data')[0].firstChild.data;
#         ajaxReq = null;
#         return data;
#     }
# }
#
# function ajaxCallBack(oHttp, job)
# {
#     if (oHttp.readyState != 4)
#         return;
#
# 	document.getElementById('tableAreaContainer').innerHTML = oHttp.responseXML.getElementsByTagName('data')[0].firstChild.data;
#
#     try
#     {
#         document.body.removeChild(document.getElementById('glass'));
#         document.body.removeChild(document.getElementById('waitImage'));
#     }
#     catch (e)
#     { }
#
#     try
#     {
#         document.getElementById('waitImage' + job.id).parentNode.removeChild(document.getElementById('waitImage' + job.id));
#     }
#     catch (e)
#     { }
#
# 	if (pivotWindow.getTop() > document.getElementById('tableAreaContainer').offsetTop + document.getElementById('tableAreaContainer').offsetHeight)
#     	placeWindow();
#
#     oHttp = null;
#
#     job.gettingData = false;
#     job.done = true;
# }
#
# function disableSort(headingList) {
# 	if (document.getElementById('sortdata')) {
# 	ds = document.getElementById('sortdata');
# 	dg = document.getElementById('sortgif')
# 		if (headingList.indexOf(",")>0) {
# 		ds.style.display='none';
# 		dg.style.display='none';
# 		}
# 		else {
# 		ds.style.display='';
# 		dg.style.display='';
# 		}
# 	}
# }
#    </script>
#    <br/>
#    <table border="0" class="tableinfotbl">
#     <tr>
#      <td class="tableinfotd1">
#       Enhed :
#       <font class="tableinfotd2">
#        Pct.
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td class="tableinfotd1">
#       Kontakt :
#       <font class="tableinfotd2">
#        Kommunikation
#        <img alt="" role="presentation" src="../Site/9/brev.gif"/>
#        <a class="" href="mailto:kommunikation@nationalbanken.dk">
#         kommunikation@nationalbanken.dk
#        </a>
#        <img alt="" role="presentation" src="../Site/9/tlf.gif"/>
#        +45 33636363
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td class="tableinfotd1">
#       Information :
#       <font class="tableinfotd2">
#        <img alt="" role="presentation" src="../Site/9/doc9.gif"/>
#        <a href="http://www.nationalbanken.dk/da/statistik/find_statistik/Sider/Renter-og-valutakurser.aspx" target="_new">
#         Vis dokumentation
#        </a>
#       </font>
#      </td>
#     </tr>
#    </table>
#    <br/>
#    <font class="normal">
#     Du kan gemme udtræk til senere brug, samt automatisk få besked når din tabel er opdateret.
#     <br/>
#     <br/>
#    </font>
#    <img alt="" role="presentation" src="../Site/9/mpil.gif"/>
#    <a class="fl" href="../NewUser/Register.asp?Maintable=DNRENTD&amp;Pxsid=9954159338065051&amp;PLanguage=0">
#     Tilmeld dig her
#    </a>
#    <script type="text/javascript">
#     $(function() {
#
# 	adjustFootnote();
#
# 	var pxtable = document.getElementById('pxtable');
#
# 	if (pxtable != null)
# 	{
# 		// Set table width automatically ...
# 		var a = pxtable.offsetWidth;
# 		var b = (self.innerWidth ? self.innerWidth : document.body.offsetWidth);
# 		if ((a / b) > 0.8) { pxtable.style.width = '97%'; }
# 		// Hover table rows ...
# 		$(".pxtable tr").not(':first').hover(
# 		function()
# 		{
# 			$(this).css("background", "#eef3fa");
# 		},
# 		function()
# 		{
# 			$(this).css("background", "");
# 		}
# 		)
# 	}
#
# });
#
# function subedit(sender)
# {
# 	if (document.rediger.pivot.selectedIndex == 2)
# 	{
# 		openPivotWindow();
# 		return false;
# 	}
# 	else
# 	{
# 		if (sender.nodeName == 'SELECT')
# 			document.rediger.submit();
# 	}
# }
#
# function showdialog(lang) {
#   $('#calcdiv').dialog('open');
#   $('#editorcalc').attr('src','../SelectOut/calculate.asp?queryfile=9954159338065051&Planguage='+lang)
#   }
#   $(document).ready(function() {
#   $('#calcdiv').dialog({autoOpen:false, height:600, width:500})
# });
#    </script>
#   </div>
#   <script src="//nationalbanken.statistikbank.dk/statbank5a/jquery/js/cookies-eu-banner.js">
#   </script>
#   <script>
#    if (typeof cookieBannerContent !== 'undefined') {
#     document.write(cookieBannerContent[0]);
#     new CookiesEuBanner(function () {
#         loadWebAnalytics();
#     }, true);
#     document.getElementById('cookies-eu-more').focus();
# }
#
# function cookiebannerupdate() {
#     document.cookie = "hasConsent=; expires=Thu, 01 Jan 1970 00:00:00 UTC; path=/;";
#     window.scrollTo(0,0);
#     location.reload();
#     }
#   </script>
#  </body>
# </html>

# %%
table = soup.find(id="pxtable")
print(type(table))
# Out:
# <class 'bs4.element.Tag'>

# %%
all_items = table.find_all('tr')
all_items
# Out:
# [<tr><th class="title" colspan="114">Rentesatser og aktieindeks (dagsobservationer) efter land,<br/>opgørelsesmetode, instrument og tid</th></tr>,
#  <tr><th class="headfirst" colspan="1" rowspan="1"> </th><th class="headfirst" colspan="1">2022M08D17</th><th class="headfirst" colspan="1">2022M08D18</th><th class="headfirst" colspan="1">2022M08D19</th><th class="headfirst" colspan="1">2022M08D22</th><th class="headfirst" colspan="1">2022M08D23</th><th class="headfirst" colspan="1">2022M08D24</th><th class="headfirst" colspan="1">2022M08D25</th><th class="headfirst" colspan="1">2022M08D26</th><th class="headfirst" colspan="1">2022M08D29</th><th class="headfirst" colspan="1">2022M08D30</th><th class="headfirst" colspan="1">2022M08D31</th><th class="headfirst" colspan="1">2022M09D01</th><th class="headfirst" colspan="1">2022M09D02</th><th class="headfirst" colspan="1">2022M09D05</th><th class="headfirst" colspan="1">2022M09D06</th><th class="headfirst" colspan="1">2022M09D07</th><th class="headfirst" colspan="1">2022M09D08</th><th class="headfirst" colspan="1">2022M09D09</th><th class="headfirst" colspan="1">2022M09D12</th><th class="headfirst" colspan="1">2022M09D13</th><th class="headfirst" colspan="1">2022M09D14</th><th class="headfirst" colspan="1">2022M09D15</th><th class="headfirst" colspan="1">2022M09D16</th><th class="headfirst" colspan="1">2022M09D19</th><th class="headfirst" colspan="1">2022M09D20</th><th class="headfirst" colspan="1">2022M09D21</th><th class="headfirst" colspan="1">2022M09D22</th><th class="headfirst" colspan="1">2022M09D23</th><th class="headfirst" colspan="1">2022M09D26</th><th class="headfirst" colspan="1">2022M09D27</th><th class="headfirst" colspan="1">2022M09D28</th><th class="headfirst" colspan="1">2022M09D29</th><th class="headfirst" colspan="1">2022M09D30</th><th class="headfirst" colspan="1">2022M10D03</th><th class="headfirst" colspan="1">2022M10D04</th><th class="headfirst" colspan="1">2022M10D05</th><th class="headfirst" colspan="1">2022M10D06</th><th class="headfirst" colspan="1">2022M10D07</th><th class="headfirst" colspan="1">2022M10D10</th><th class="headfirst" colspan="1">2022M10D11</th><th class="headfirst" colspan="1">2022M10D12</th><th class="headfirst" colspan="1">2022M10D13</th><th class="headfirst" colspan="1">2022M10D14</th><th class="headfirst" colspan="1">2022M10D17</th><th class="headfirst" colspan="1">2022M10D18</th><th class="headfirst" colspan="1">2022M10D19</th><th class="headfirst" colspan="1">2022M10D20</th><th class="headfirst" colspan="1">2022M10D21</th><th class="headfirst" colspan="1">2022M10D24</th><th class="headfirst" colspan="1">2022M10D25</th><th class="headfirst" colspan="1">2022M10D26</th><th class="headfirst" colspan="1">2022M10D27</th><th class="headfirst" colspan="1">2022M10D28</th><th class="headfirst" colspan="1">2022M10D31</th><th class="headfirst" colspan="1">2022M11D01</th><th class="headfirst" colspan="1">2022M11D02</th><th class="headfirst" colspan="1">2022M11D03</th><th class="headfirst" colspan="1">2022M11D04</th><th class="headfirst" colspan="1">2022M11D07</th><th class="headfirst" colspan="1">2022M11D08</th><th class="headfirst" colspan="1">2022M11D09</th><th class="headfirst" colspan="1">2022M11D10</th><th class="headfirst" colspan="1">2022M11D11</th><th class="headfirst" colspan="1">2022M11D14</th><th class="headfirst" colspan="1">2022M11D15</th><th class="headfirst" colspan="1">2022M11D16</th><th class="headfirst" colspan="1">2022M11D17</th><th class="headfirst" colspan="1">2022M11D18</th><th class="headfirst" colspan="1">2022M11D21</th><th class="headfirst" colspan="1">2022M11D22</th><th class="headfirst" colspan="1">2022M11D23</th><th class="headfirst" colspan="1">2022M11D24</th><th class="headfirst" colspan="1">2022M11D25</th><th class="headfirst" colspan="1">2022M11D28</th><th class="headfirst" colspan="1">2022M11D29</th><th class="headfirst" colspan="1">2022M11D30</th><th class="headfirst" colspan="1">2022M12D01</th><th class="headfirst" colspan="1">2022M12D02</th><th class="headfirst" colspan="1">2022M12D05</th><th class="headfirst" colspan="1">2022M12D06</th><th class="headfirst" c ...
#  <tr><td class="stub1" rowspan="1">DK: Danmark</td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td></tr>,
#  <tr><td class="stub2" rowspan="1">Daglige renter (procent)</td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td><td class="Nn"></td></tr>,
#  <tr><td class="stub3">Nationalbankens rente - Diskonto (Aug. 1987-)</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,0000</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td></tr>,
#  <tr><td class="stub3">Nationalbankens rente - Folioindskud (Aug 1987- )</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td></tr>,
#  <tr><td class="stub3">Nationalbankens rente - Udlån (Apr. 1992-)</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,0500</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">0,8000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,4000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td><td class="No">1,9000</td></tr>,
#  <tr><td class="stub3">Nationalbankens rente - Indskudsbeviser (Apr. 1992-)</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">-0,1000</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">0,6500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,2500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td><td class="No">1,7500</td></tr>,
#  <tr><td class="footnote" colspan="114"><br/>Historiske data for afsluttede serier kan findes på Danmarks Nationalbanks <a href="https://www.nationalbanken.dk/da/statistik/find_statistik/Documents/Specifikation%20til%20Nationalbankens%20balance/Arkiv_DNRENTD.csv" target="_new">hjemmeside</a> <br/></td></tr>]

# %%
periods = [pt.get_text() for pt in all_items]
periods
# Out:
# ['Rentesatser og aktieindeks (dagsobservationer) efter land,opgørelsesmetode, instrument og tid',
#  '\...',
#  'DK: Danmark',
#  'Daglige renter (procent)',
#  'Nationalbankens rente - Diskonto (Aug. 1987-)0,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,00000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,7500',
#  'Nationalbankens rente - Folioindskud (Aug 1987- )-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,10000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,7500',
#  'Nationalbankens rente - Udlån (Apr. 1992-)0,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,05000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80000,80001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,40001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,90001,9000',
#  'Nationalbankens rente - Indskudsbeviser (Apr. 1992-)-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,1000-0,10000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65000,65001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,25001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,75001,7500',
#  'Historiske data for afsluttede serier kan findes på Danmarks Nationalbanks hjemmeside ']

# %%
period_names = [pn.get_text() for pn in table.select(".pxtable .headfirst")]
print(period_names)
# Out:
# ['\xa0', '2022M08D17', '2022M08D18', '2022M08D19', '2022M08D22', '2022M08D23', '2022M08D24', '2022M08D25', '2022M08D26', '2022M08D29', '2022M08D30', '2022M08D31', '2022M09D01', '2022M09D02', '2022M09D05', '2022M09D06', '2022M09D07', '2022M09D08', '2022M09D09', '2022M09D12', '2022M09D13', '2022M09D14', '2022M09D15', '2022M09D16', '2022M09D19', '2022M09D20', '2022M09D21', '2022M09D22', '2022M09D23', '2022M09D26', '2022M09D27', '2022M09D28', '2022M09D29', '2022M09D30', '2022M10D03', '2022M10D04', '2022M10D05', '2022M10D06', '2022M10D07', '2022M10D10', '2022M10D11', '2022M10D12', '2022M10D13', '2022M10D14', '2022M10D17', '2022M10D18', '2022M10D19', '2022M10D20', '2022M10D21', '2022M10D24', '2022M10D25', '2022M10D26', '2022M10D27', '2022M10D28', '2022M10D31', '2022M11D01', '2022M11D02', '2022M11D03', '2022M11D04', '2022M11D07', '2022M11D08', '2022M11D09', '2022M11D10', '2022M11D11', '2022M11D14', '2022M11D15', '2022M11D16', '2022M11D17', '2022M11D18', '2022M11D21', '2022M11D22', '2022M11D23', '2022M11D24', '2022M11D25', '2022M11D28', '2022M11D29', '2022M11D30', '2022M12D01', '2022M12D02', '2022M12D05', '2022M12D06', '2022M12D07', '2022M12D08', '2022M12D09', '2022M12D12', '2022M12D13', '2022M12D14', '2022M12D15', '2022M12D16', '2022M12D19', '2022M12D20', '2022M12D21', '2022M12D22', '2022M12D23', '2022M12D27', '2022M12D28', '2022M12D29', '2022M12D30', '2023M01D02', '2023M01D03', '2023M01D04', '2023M01D05', '2023M01D06', '2023M01D09', '2023M01D10', '2023M01D11', '2023M01D12', '2023M01D13', '2023M01D16', '2023M01D17', '2023M01D18', '2023M01D19', '2023M01D20', '2023M01D23']

# %%
list = []
for x in table.find_all('tr'):
    nationalbankes_r = [na.get_text() for na in x.select(".No")]
    list.append(nationalbankes_r)

# %%
df = pd.DataFrame.from_dict({
    'Date': period_names[1:],
    'Nationalbankens rente - Diskonto (Aug. 1987- )': list[4],
    'Nationalbankens rente - Folioindskud (Aug 1987- )': list[5],
    'Nationalbankens rente - Udlån (Apr. 1992-)': list[6],
    'Nationalbankens rente - Indskudsbeviser (Apr. 1992-)': list[7]
}).set_index('Date')

df['Nationalbankens rente - Diskonto (Aug. 1987- )'] = df['Nationalbankens rente - Diskonto (Aug. 1987- )'].str.replace(',','.').astype(float)
df['Nationalbankens rente - Folioindskud (Aug 1987- )'] = df['Nationalbankens rente - Folioindskud (Aug 1987- )'].str.replace(',','.').astype(float)
df['Nationalbankens rente - Udlån (Apr. 1992-)'] = df['Nationalbankens rente - Udlån (Apr. 1992-)'].str.replace(',','.').astype(float)
df['Nationalbankens rente - Indskudsbeviser (Apr. 1992-)'] = df['Nationalbankens rente - Indskudsbeviser (Apr. 1992-)'].str.replace(',','.').astype(float)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of             Nationalbankens rente - Diskonto (Aug. 1987- )  \
# Date
# 2022M08D17                                            0.00
# 2022M08D18                                            0.00
# 2022M08D19                                            0.00
# 2022M08D22                                            0.00
# 2022M08D23                                            0.00
# ...                                                    ...
# 2023M01D17                                            1.75
# 2023M01D18                                            1.75
# 2023M01D19                                            1.75
# 2023M01D20                                            1.75
# 2023M01D23                                            1.75
#
#             Nationalbankens rente - Folioindskud (Aug 1987- )  \
# Date
# 2022M08D17                                              -0.10
# 2022M08D18                                              -0.10
# 2022M08D19                                              -0.10
# 2022M08D22                                              -0.10
# 2022M08D23                                              -0.10
# ...                                                       ...
# 2023M01D17                                               1.75
# 2023M01D18                                               1.75
# 2023M01D19                                               1.75
# 2023M01D20                                               1.75
# 2023M01D23                                               1.75
#
#             Nationalbankens rente - Udlån (Apr. 1992-)  \
# Date
# 2022M08D17                                        0.05
# 2022M08D18                                        0.05
# 2022M08D19                                        0.05
# 2022M08D22                                        0.05
# 2022M08D23                                        0.05
# ...                                                ...
# 2023M01D17                                        1.90
# 2023M01D18                                        1.90
# 2023M01D19                                        1.90
# 2023M01D20                                        1.90
# 2023M01D23                                        1.90
#
#             Nationalbankens rente - Indskudsbeviser (Apr. 1992-)
# Date
# 2022M08D17                                              -0.10
# 2022M08D18                                              -0.10
# 2022M08D19                                              -0.10
# 2022M08D22                                              -0.10
# 2022M08D23                                              -0.10
# ...                                                       ...
# 2023M01D17                                               1.75
# 2023M01D18                                               1.75
# 2023M01D19                                               1.75
# 2023M01D20                                               1.75
# 2023M01D23                                               1.75
#
# [113 rows x 4 columns]>
